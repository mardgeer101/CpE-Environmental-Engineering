# %% [markdown]
# ### 1 🌱 What is Environmental Engineering?
#
# **Definition:**
# Environmental Engineering is the branch of engineering concerned with applying scientific and engineering principles to improve and protect the environment. This includes reducing pollution, managing waste, conserving natural resources, and developing sustainable technologies to enhance the quality of life and ecosystem health.
#
# Environmental engineers design systems that treat water, manage waste, control air pollution, and monitor environmental hazards. For computer engineers, this field opens opportunities to innovate using technology such as sensors, IoT, and data analytics to solve environmental problems.
#
# **Key Areas of Focus:**
# - Water and air pollution control
# - Waste management and recycling
# - Environmental monitoring
# - Sustainable design and development
# - Application of smart technologies for sustainability
#
# **Relevance to BSCpE:**
# Computer engineers play a vital role in:
# - Developing intelligent monitoring systems using IoT
# - Creating energy-efficient embedded devices
# - Using machine learning to predict environmental conditions
# - Designing apps and dashboards for environmental awareness
#
# **Reference:**
# Mihelcic, J. R., & Zimmerman, J. B. (2014). *Environmental Engineering: Fundamentals, Sustainability, Design*. Wiley.

# %% [markdown]
# ### 1.2 Scope of Environmental Engineering in BSCpE
# - Environmental monitoring using sensors and IoT
# - Smart and energy-efficient systems
# - Green computing and reduced e-waste
# - AI-based forecasting and automation for sustainability
#
# ---
#
# ### 1.3 🌍 Global Environmental Challenges
#
# Environmental challenges are pressing issues that affect ecosystems, human health, and sustainable development. Understanding these challenges is essential for computer engineers aiming to create impactful, tech-driven environmental solutions.
#
# ---
#
# #### 🌀 1. Climate Change
# **Definition:** A long-term change in temperature and weather patterns, primarily caused by human activities such as the burning of fossil fuels.
# **Impacts:**
# - Rising global temperatures
# - Melting ice caps and rising sea levels
# - Increased frequency of extreme weather events (typhoons, droughts, floods)
#
#
# **Reference:**
# IPCC (2023). *Climate Change 2023: Synthesis Report*. [https://www.ipcc.ch/report/ar6/syr/](https://www.ipcc.ch/report/ar6/syr/)
#
# ---
# #### 🌫️ 2. Air and Water Pollution
# **Air Pollution:** Emission of harmful substances (PM2.5, NO₂, CO₂) into the atmosphere from vehicles, factories, and burning of biomass.
# **Water Pollution:** Contamination of water bodies due to sewage discharge, industrial waste, and agricultural runoff.
# **Impacts:**
# - Respiratory and cardiovascular diseases
# - Unsafe drinking water and waterborne illnesses
# - Ecosystem damage
#
#
# **Reference:**
# World Health Organization (2022). *Air pollution*. [https://www.who.int/health-topics/air-pollution](https://www.who.int/health-topics/air-pollution)
# UNEP (2021). *Water Pollution: Causes, Effects and Control*. [https://www.unep.org/](https://www.unep.org/)
#
# ---
#
# #### 🐾 3. Biodiversity Loss
# **Definition:** The rapid reduction of species diversity due to habitat destruction, pollution, overexploitation, and climate change.
# **Impacts:**
# - Loss of ecological balance
# - Reduced availability of food and natural resources
# - Extinction of endemic species
#
#
# **Reference:**
# WWF (2022). *Living Planet Report 2022*. [https://www.worldwildlife.org/publications/living-planet-report-2022](https://www.worldwildlife.org/publications/living-planet-report-2022)
#
# ---
#
# #### 🪨 4. Resource Depletion
# **Definition:** The excessive use of natural resources—such as fossil fuels, water, minerals, and forests—faster than they can be replenished.
# **Impacts:**
# - Energy scarcity
# - Water shortages
# - Deforestation and land degradation
#
#
# **Reference:**
# United Nations (2020). *Global Resources Outlook*. [https://www.resourcepanel.org/reports/global-resources-outlook](https://www.resourcepanel.org/reports/global-resources-outlook)
#
# ---
#
# These challenges serve as inspiration for computer engineers to innovate technologies that promote **sustainability**, **resource efficiency**, and **environmental resilience**.
#
#
# ---

# %% [markdown]
# ### 1.4 United Nations Sustainable Development Goals (SDGs)
# Key SDGs related to the environment:
# - SDG 6: Clean Water and Sanitation
# - SDG 7: Affordable and Clean Energy
# - SDG 11: Sustainable Cities and Communities
# - SDG 12: Responsible Consumption and Production
# - SDG 13: Climate Action
#
# ![image.png](attachment:95221043-789d-472f-a7a4-2d9f8437dc8e.png)
#
# **Website:** [https://sdgs.un.org/goals](https://sdgs.un.org/goals)
#
# ---

# %% [markdown]
# ### 1.5 Role of Engineers in Environmental Sustainability
# - Innovating green technologies
# - Designing low-power systems
# - Analyzing environmental data for informed decision-making
# - Leading community-based environmental programs
#
# ---

# %% [markdown]
# #### Case Study 1: Smart Air Quality Monitoring System
# A city government uses IoT sensors to monitor PM2.5 and CO₂ levels across school zones. Data is collected in real time and displayed on a mobile app to help parents and schools plan outdoor activities.
#
# **Technologies used:**
# - MQ-135 air sensor
# - ESP8266 microcontroller
# - Firebase Realtime Database
# - Mobile app dashboard
#
# **Reference**
# Hasenfratz, D., Saukh, O., Sturzenegger, S., & Thiele, L. (2012).*Mobile Sensing: From Smartphones and Wearables to Big Data*, ACM.
# [Available the Journal Here](https://www.bing.com/ck/a?!&&p=2c72911986d72df87955c451ee603c233648e9f0eff2bd633d39cf5eff483a41JmltdHM9MTc0MzU1MjAwMA&ptn=3&ver=2&hsh=4&fclid=0c695fe9-f874-634c-14e7-4a85f9e962d2&psq=Hasenfratz%2c+D.%2c+Saukh%2c+O.%2c+Sturzenegger%2c+S.%2c+%26+Thiele%2c+L.+(2012).Mobile+Sensing%3a+From+Smartphones+and+Wearables+to+Big+Data%2c+ACM.&u=a1aHR0cDovL29sZ2FzYXVraC5jb20vcGFwZXIvaGFzZW5mcmF0ejEycGFydGljaXBhdG9yeS5wZGY&ntb=1)

# %% [markdown]
# #### Case Study 2: Smart Waste Bin with IoT and Weight Sensors
# **Problem:** Urban areas experience inefficient waste collection, leading to overfilled bins, foul odors, and public health issues.
# **Solution:** A smart waste bin is developed using ultrasonic sensors and weight sensors to monitor fill level and type of waste. Data is transmitted via Wi-Fi to a centralized system that notifies waste collectors and tracks bin usage.
#
# **Technologies Used:**
# - Arduino + weight sensors
# - Ultrasonic distance sensors
# - Wi-Fi module (ESP8266)
# - Web dashboard for monitoring
# - Machine learning to classify waste (optional extension)
#
# **Relevance to CpE:**
# Involves embedded systems, wireless communication, and basic ML integration—applicable in smart city development and e-waste reduction initiatives.
#
# **Reference:**
# Shah, A. et al. (2021). *A review of IoT-based smart waste level monitoring system for smart cities.*
# [Available on Google Scholar](https://scholar.google.com/scholar?q=IoT+based+smart+waste+monitoring+system)
#
# ---

# %% [markdown]
# #### Case Study 3: AI-Powered Energy Monitoring in Smart Homes
# **Problem:** Households often face high electricity bills and have limited knowledge of energy consumption patterns.
# **Solution:** A smart energy monitoring system is developed that tracks energy usage per device and uses AI to suggest optimizations or automatically shut down idle devices. Solar energy integration allows excess power redistribution within the home.
#
# **Technologies Used:**
# - Smart plugs with power sensors (e.g., HLW8012)
# - Microcontroller with Wi-Fi (ESP32)
# - AI model for usage pattern analysis
# - Cloud dashboard for monitoring
# - Optional solar energy integration and threshold-based automation
#
# **Relevance to CpE:**
# Engages students in home automation, edge AI, and renewable energy systems—key themes in sustainable computing.
#
# **Reference:**
# Bahman, M. M. et al. (2022). *Energy-saving owing to using PCM into buildings: Considering of hot and cold climate region.*
# [https://doi.org/10.1016/j.seta.2022.102112](https://doi.org/10.1016/j.seta.2022.102112)
